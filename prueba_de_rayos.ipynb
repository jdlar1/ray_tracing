# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rayos = np.load('marte_matrix_output.npy')

# %%
rayos.shape
# Out:
# (189, 189, 3, 5)

# %%
for imagen in range(rayos.shape[3]):
    plt.title(f'Rayo #{imagen}')
    plt.imshow(rayos[:,:,:,imagen])
    plt.show()
